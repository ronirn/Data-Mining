# %%
import pandas as pd
data = pd.read_csv('G:\\DATA MINING//Automobile_data.csv')
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.head(50)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
data.head(130)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 125          3               186      porsche       gas        std
# 126          3                 ?      porsche       gas        std
# 127          3                 ?      porsche       gas        std
# 128          3                 ?      porsche       gas        std
# 129          1                 ?      porsche       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
update_data = data.drop([data.index[9], data.index[44], data.index[45], data.index[129]])

# %%
update_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    object
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
update_data['price']=update_data['price'].astype('int')

# %%
update_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    object
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
update_data.hist(column='price', bins=30)
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
update_data.hist(column='price', by='drive-wheels', bins=20)
# Out:
# array([[<Axes: title={'center': '4wd'}>, <Axes: title={'center': 'fwd'}>],
#        [<Axes: title={'center': 'rwd'}>, <Axes: >]], dtype=object)

# %%
update_data.head(60)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# ...

# %%
update_data = data.drop([data.index[55], data.index[56], data.index[57], data.index[58]])

# %%
update_data['bore']=update_data['bore'].astype('float')

# %%
update_data['stroke']=update_data['stroke'].astype('float')

# %%
update_data.head(60)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# ...

# %%
update_data[['bore', 'stroke']].plot(kind='hist',alpha=0.7, bins=30,rot=45,figsize=(12,8),color=['red','blue'])
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
from scipy import stats

print("Tipe data sebelum konversi:")
print(update_data['wheel-base'].dtype)
print(update_data['price'].dtype)

# Konversi kolom 'wheel-base' dan 'price' ke tipe numerik, dan ubah nilai non-numerik menjadi NaN
update_data['wheel-base'] = pd.to_numeric(update_data['wheel-base'], errors='coerce')
update_data['price'] = pd.to_numeric(update_data['price'], errors='coerce')

# Cek tipe data setelah konversi
print("Tipe data setelah konversi:")
print(update_data['wheel-base'].dtype)
print(update_data['price'].dtype)

# Hapus baris yang mengandung NaN di kolom 'wheel-base' dan 'price'
update_data = update_data.dropna(subset=['wheel-base', 'price'])

# Cek apakah ada NaN yang tersisa
print("Jumlah missing values setelah pembersihan:")
print(update_data[['wheel-base', 'price']].isna().sum())

# Hitung koefisien korelasi Pearson
pearson_coef, p_value = stats.pearsonr(update_data['wheel-base'], update_data['price'])

# Tampilkan hasil
print('Korelasi Pearson Koefisien adalah', pearson_coef, 'dengan p-value', p_value)
# Out:
# Tipe data sebelum konversi:
# float64
# float64
# Tipe data setelah konversi:
# float64
# float64
# Jumlah missing values setelah pembersihan:
# wheel-base    0
# price         0
# dtype: int64
# Korelasi Pearson Koefisien adalah 0.5866608117384277 dengan p-value 1.3211894677281557e-19

# %%
update_data.info(60)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 197 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          197 non-null    int64
#  1   normalized-losses  197 non-null    object
#  2   make               197 non-null    object
#  3   fuel-type          197 non-null    object
#  4   aspiration         197 non-null    object
#  5   num-of-doors       197 non-null    object
#  6   body-style         197 non-null    object
#  7   drive-wheels       197 non-null    object
#  8   engine-location    197 non-null    object
#  9   wheel-base         197 non-null    float64
#  10  length             197 non-null    float64
#  11  width              197 non-null    float64
#  12  height             197 non-null    float64
#  13  curb-weight        197 non-null    int64
#  14  engine-type        197 non-null    object
#  15  num-of-cylinders   197 non-null    object
# ...
